# %% [markdown]
# # Homework 4
#
# MATH 104A Intro to Numerical Analysis
#
# Harry Coleman
#
# December 16, 2020

# %% [markdown]
# ## 3

# %%
from math import cos, sin, pi, exp
from numpy.fft import rfft
import matplotlib.pyplot as plt
        

def P(N, A, B, x):
    return A[0]/2 \
            + sum([A[k]*cos(k*x) + B[k]*sin(k*x) \
                   for k in range(1, int(N/2))]) \
            + A[-1]/2*cos(N/2*x)

def main_3a():
    N = 8
    X = [j*2*pi/N for j in range(0, N)]
    F = [exp(sin(x)) for x in X]
    
    C = rfft(F)
    A = 2/N * C.real
    B = -2/N * C.imag
    
    M = 1000
    X_dom = [2*pi*l/M for l in range(0, M+1)]
    F_val = [exp(sin(x)) for x in X_dom]
    P_val = [P(N, A, B, x) for x in X_dom]
    
    plt.plot(X_dom, F_val)
    plt.show()
    
    plt.plot(X_dom, F_val)
    plt.plot(X_dom, P_val)
    plt.plot(X, F, 'ro')
    plt.show()
    
main_3a()

# %%
def dP(N, A, B, x):
    return sum([k*(B[k]*cos(k*x) - A[k]*sin(k*x)) \
                   for k in range(1, int(N/2))]) \
            + N*A[-1]*sin(N/2*x)

def main_3b():
    N = 8
    X = [j*2*pi/N for j in range(0, N)]
    F = [exp(sin(x)) for x in X]
    
    C = rfft(F)
    A = 2/N * C.real
    B = -2/N * C.imag
    
    M = 1000
    X_dom = [2*pi*l/M for l in range(0, M+1)]
    dF_val = [cos(x)*exp(sin(x)) for x in X_dom]
    dP_val = [dP(N, A, B, x) for x in X_dom]
    
    plt.plot(X_dom, dF_val)
    plt.plot(X_dom, dP_val)
    plt.show()
    
    for x in X:
        print(dP(N, A, B, x), cos(x)*exp(sin(x)) - dP(N, A, B, x))
    
main_3b()
# Out:
# 0.995682088901413 0.004317911098587035
# 1.4375429562572415 -0.003449099708283221
# 2.797812703975646e-17 1.3846862998038274e-16
# -1.437542956257241 0.003449099708282999
# -0.9956820889014132 -0.004317911098587035
# -0.3513816866267539 0.0027294713504026347
# -3.5646821280815794e-17 -3.193153573459279e-17
# 0.35138168662675356 -0.0027294713504025236
